# %%
# Importar bibliotecas
import pandas as pd
from google.colab import files

# Passo 1: Fazer upload do arquivo
print("📁 Faça upload do arquivo chamado 'clientes2.csv':")
uploaded = files.upload()

# Passo 2: Ler os dados do arquivo
df = pd.read_csv("clientes2.csv")

# Passo 3: Visualização geral
print("✅ Primeiras linhas do arquivo:")
display(df.head())

print("\n📊 Informações do DataFrame:")
print(df.info())

print("\n🔍 Contagem de valores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# 📁 Faça upload do arquivo chamado 'clientes2.csv':
#      <input type="file" id="files-6390012a-4beb-4bc5-9c9b-9d443dc8e8a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6390012a-4beb-4bc5-9c9b-9d443dc8e8a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# Preencher valores ausentes em 'idade' com a média
df['idade'] = df['idade'].fillna(df['idade'].mean())

# Preencher sexo com moda
df['sexo'] = df['sexo'].fillna(df['sexo'].mode()[0])

# Visualizar após tratamento
print("✅ Dados após preenchimento:")
display(df)
# Out:
# ✅ Dados após preenchimento:
#    id   nome  idade       sexo          cidade
# 0   1    Ana  28.00   Feminino       São Paulo
# 1   2   João  31.25  Masculino  Rio de Janeiro
# 2   3  Carla  35.00   Feminino  Belo Horizonte
# 3   4  Pedro  22.00   Feminino        Curitiba
# 4   5  Lucas  40.00  Masculino    Porto Alegre

# %%
import pandas as pd
from google.colab import files

# Upload do arquivo
print("📁 Faça upload do arquivo 'clima_julho.csv'")
uploaded = files.upload()

# Leitura do CSV
df = pd.read_csv('clima_julho.csv')

# Visualização inicial
print("📊 Dados brutos:")
display(df)

# Contar valores ausentes
print("🔍 Valores ausentes por coluna:")
print(df.isnull().sum())

# Preenchimento com métodos diferentes
df_temp = df.copy()
df_temp['temperatura'] = df_temp['temperatura'].interpolate()
df_temp['chuva_mm'] = df_temp['chuva_mm'].fillna(0)  # assuma que faltantes = sem chuva

# Mostrar resultado
print("✅ Após preenchimento (temp = interpolação, chuva = 0):")
display(df_temp)

# Salvar CSV limpo
df_temp.to_csv('clima_julho_tratado.csv', index=False)
print("📁 Arquivo tratado salvo como 'clima_julho_tratado.csv'")
# Out:
# 📁 Faça upload do arquivo 'clima_julho.csv'
#      <input type="file" id="files-80382037-57d1-4fc3-a77e-f9feee058c5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80382037-57d1-4fc3-a77e-f9feee058c5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
